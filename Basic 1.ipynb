# %%
i = 10

# %%
print(i)
# Out:
# 10

# %%
type(i)
# Out:
# int

# %%
i = "WELCOME"

# %%
print(i)
# Out:
# WELCOME

# %%
type(i)
# Out:
# str

# %%
len(i)
# Out:
# 7

# %%
i[0]
# Out:
# 'W'

# %% [markdown]
# #

# %%
i[1]
# Out:
# 'E'

# %%
i[2]
# Out:
# 'L'

# %%
i[3]
# Out:
# 'C'

# %%
i[4]
# Out:
# 'O'

# %%
i[5]
# Out:
# 'M'

# %%
i[6]
# Out:
# 'E'

# %%
i[-1]
# Out:
# 'E'

# %%
i[-2]
# Out:
# 'M'

# %%
i[-3]
# Out:
# 'O'

# %%
i[-4]
# Out:
# 'C'

# %%
i[-5]
# Out:
# 'L'

# %%
i[-6]
# Out:
# 'E'

# %%
i[-7]
# Out:
# 'W'

# %%
print(i[4],i[-6])
# Out:
# O E

# %%
i[0:5]
# Out:
# 'WELCO'

# %%
i[-6:-2]
# Out:
# 'ELCO'

# %%
i[4:10]
# Out:
# 'OME'

# %%
i[-4:]
# Out:
# 'COME'

# %%
i[6:2]
# Out:
# ''

# %%
msg = "Welcome To Python Programming Class"

# %%
msg
# Out:
# 'Welcome To Python Programming Class'

# %%
len(msg)
# Out:
# 35

# %%
msg[30:35]
# Out:
# 'Class'

# %%
msg[-5:35]
# Out:
# 'Class'

# %%
msg[-5:]
# Out:
# 'Class'

# %%
folder = "C:\newfolder"

# %%
print(folder)
# Out:
# C:
# ewfolder

# %%
folder = "C:\\newfolder"

# %%
print(folder)
# Out:
# C:\newfolder

# %%
folder = r"C:\newfolder"

# %%
print(folder)
# Out:
# C:\newfolder

# %%
s = "WELCOME"

# %%
s + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-30fc4c06cb2b> in <module>
# ----> 1 s + 10
#
# TypeError: can only concatenate str (not "int") to str

# %%
s+"10"
# Out:
# 'WELCOME10'

# %%
s*4
# Out:
# 'WELCOMEWELCOMEWELCOMEWELCOME'

# %%
languages = ["Python","C","C++","JAVA"]

# %%
print(languages)
# Out:
# ['Python', 'C', 'C++', 'JAVA']

# %%
type(languages)
# Out:
# list

# %%
len(languages)
# Out:
# 4

# %%
languages[0]
# Out:
# 'Python'

# %%
languages[1]
# Out:
# 'C'

# %%
languages[2]
# Out:
# 'C++'

# %%
languages[3]
# Out:
# 'JAVA'

# %%
languages[-2]
# Out:
# 'C++'

# %%
languages[0][0]
# Out:
# 'P'

# %%
languages[0][-2]
# Out:
# 'o'

# %%
languages[0][-2:]
# Out:
# 'on'

# %%
languages[0][4:]
# Out:
# 'on'

# %%
languages[0:2]
# Out:
# ['Python', 'C']

# %%
languages[0:4]
# Out:
# ['Python', 'C', 'C++', 'JAVA']

# %%
languages.append('Ruby')

# %%
languages
# Out:
# ['Python', 'C', 'C++', 'JAVA', 'Ruby']

# %%
languages.insert(1,"Pascal")

# %%
languages
# Out:
# ['Python', 'Pascal', 'C', 'C++', 'JAVA', 'Ruby']

# %%
languages.remove('JAVA')

# %%
languages
# Out:
# ['Python', 'Pascal', 'C', 'C++', 'Ruby']

# %%
languages.pop(1)
# Out:
# 'Pascal'

# %%
languages
# Out:
# ['Python', 'C', 'C++', 'Ruby']

# %%
numlist = [100,200,300]

# %%
numlist
# Out:
# [100, 200, 300]

# %%
languages.append(numlist)

# %%
languages
# Out:
# ['Python', 'C', 'C++', 'Ruby', 'Numlist', [100, 200, 300]]

# %%
languages.remove('Numlist')

# %%
languages
# Out:
# ['Python', 'C', 'C++', 'Ruby', [100, 200, 300]]

# %%
anlist = [1,2,3,4]

# %%
languages.extend(anlist)

# %%
languages
# Out:
# ['Python', 'C', 'C++', 'Ruby', [100, 200, 300], 1, 2, 3, 4]

# %%
len(languages)
# Out:
# 9

# %%
len(anlist)
# Out:
# 4

# %%
teams = ["RCB","CSK"]

# %%
languages.insert(2,teams)

# %%
languages
# Out:
# ['Python', 'C', ['RCB', 'CSK'], 'C++', 'Ruby', [100, 200, 300], 1, 2, 3, 4]

# %%
languages.append(s)

# %%
languages
# Out:
# ['Python',
#  'C',
#  ['RCB', 'CSK'],
#  'C++',
#  'Ruby',
#  [100, 200, 300],
#  1,
#  2,
#  3,
#  4,
#  'WELCOME']

# %%
languages.extend(s)

# %%
languages
# Out:
# ['Python',
#  'C',
#  ['RCB', 'CSK'],
#  'C++',
#  'Ruby',
#  [100, 200, 300],
#  1,
#  2,
#  3,
#  4,
#  'WELCOME',
#  'W',
#  'E',
#  'L',
#  'C',
#  'O',
#  'M',
#  'E']

# %%
languages.append(12345)

# %%
languages
# Out:
# ['Python',
#  'C',
#  ['RCB', 'CSK'],
#  'C++',
#  'Ruby',
#  [100, 200, 300],
#  1,
#  2,
#  3,
#  4,
#  'WELCOME',
#  'W',
#  'E',
#  'L',
#  'C',
#  'O',
#  'M',
#  'E',
#  12345]

# %%
a = "56789"

# %%
languages.append(a)

# %%
languages
# Out:
# ['Python',
#  'C',
#  ['RCB', 'CSK'],
#  'C++',
#  'Ruby',
#  [100, 200, 300],
#  1,
#  2,
#  3,
#  4,
#  'WELCOME',
#  'W',
#  'E',
#  'L',
#  'C',
#  'O',
#  'M',
#  'E',
#  12345,
#  '56789']

# %%
languages.extend(a)

# %%
languages
# Out:
# ['Python',
#  'C',
#  ['RCB', 'CSK'],
#  'C++',
#  'Ruby',
#  [100, 200, 300],
#  1,
#  2,
#  3,
#  4,
#  'WELCOME',
#  'W',
#  'E',
#  'L',
#  'C',
#  'O',
#  'M',
#  'E',
#  12345,
#  '56789',
#  '5',
#  '6',
#  '7',
#  '8',
#  '9']

# %%
teams.count("RCB")
# Out:
# 1

# %%
languages.count("E")
# Out:
# 2

# %%
languages.count(100)
# Out:
# 0

# %%
len(languages)
# Out:
# 25

# %%
languages.pop(len(languages)-3)
# Out:
# '7'

# %%
languages[5]
# Out:
# [100, 200, 300]

# %%
languages[5][0]
# Out:
# 100

# %%
del languages[1]

# %%
languages
# Out:
# ['Python',
#  ['RCB', 'CSK'],
#  'C++',
#  'Ruby',
#  [100, 200, 300],
#  1,
#  2,
#  3,
#  4,
#  'WELCOME',
#  'W',
#  'E',
#  'L',
#  'C',
#  'O',
#  'M',
#  'E',
#  12345,
#  '56789',
#  '5',
#  '6',
#  '8',
#  '9']

# %%
languages.index("C++")
# Out:
# 2

# %%
del  languages[-5:]

# %%
languages
# Out:
# ['Python',
#  ['RCB', 'CSK'],
#  'C++',
#  'Ruby',
#  [100, 200, 300],
#  1,
#  2,
#  3,
#  4,
#  'WELCOME',
#  'W',
#  'E',
#  'L',
#  'C',
#  'O',
#  'M',
#  'E',
#  12345]

# %%
len(languages)
# Out:
# 18

# %%
languages.clear()

# %%
languages
# Out:
# []

# %%
languages = ["Golang","Pearl","C#"]

# %%
languages
# Out:
# ['Golang', 'Pearl', 'C#']

# %%
languages[2]
# Out:
# 'C#'

# %%
languages[2] = "C-Sharp"

# %%
languages
# Out:
# ['Golang', 'Pearl', 'C-Sharp']

# %%
s = "WELCOME"

# %%
type(s)
# Out:
# str

# %%
type(languages)
# Out:
# list

# %%
s = 'Hello,"How Are You"'

# %%
print(s)
# Out:
# Hello,"How Are You"

# %%
s1 = 'Hello'

# %%
s2 = "How Are You"

# %%
print(s1+s2)
# Out:
# HelloHow Are You

# %%
print(s1+str(s2))
# Out:
# HelloHow Are You

# %%
print(s1+" "+s2)
# Out:
# Hello How Are You
