# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanvee0306/Python-For-Data-Scientist/blob/main/Tuples%2C_%3D_Operator%2C_Shallow_Copy_%26_Deep_Copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Tuples
# * Ordered Collection of items/elements
# * IMMUTABLE
# * Syntax : ( )

# %%
players = ("Rohit", "Virat", "Rahane")

# %%
print(players)
# Out:
# ('Rohit', 'Virat', 'Rahane')

# %%
type(players)
# Out:
# tuple

# %% [markdown]
# #### To access any element, use [ ] - Square or Subscript Operator

# %%
players[0]
# Out:
# 'Rohit'

# %%
len(players)
# Out:
# 3

# %%
players[-1]
# Out:
# 'Rahane'

# %%
players[:2]
# Out:
# ('Rohit', 'Virat')

# %%
players.count("Virat")
# Out:
# 1

# %%
players.index("Virat")
# Out:
# 1

# %%
t = (100, [1, 2, 3], "March", 2021)

# %%
t
# Out:
# (100, [1, 2, 3], 'March', 2021)

# %%
players
# Out:
# ('Rohit', 'Virat', 'Rahane')

# %%
players[0] = "Rohit Sharma"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-7cb99da21ae0> in <module>()
# ----> 1 players[0] = "Rohit Sharma"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t
# Out:
# (100, [1, 2, 3], 'March', 2021)

# %%
t[1]
# Out:
# [1, 2, 3]

# %%
t[1].append(4)

# %%
t
# Out:
# (100, [1, 2, 3, 4], 'March', 2021)

# %%
t[0] = "hundred"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-fb37603149b3> in <module>()
# ----> 1 t[0] = "hundred"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t[1] = "18"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-32dad696ccfd> in <module>()
# ----> 1 t[1] = "18"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t[1].append(5)

# %%
t
# Out:
# (100, [1, 2, 3, 4, 5], 'March', 2021)

# %% [markdown]
# ### =, Shallow Copy & Deep Copy

# %%
team_a = ["Dhawan", "Rahane", "Ashwin"]

# %%
team_b = team_a

# %%
team_b
# Out:
# ['Dhawan', 'Rahane', 'Ashwin']

# %%
id(team_a)
# Out:
# 139746837760032

# %%
id(team_b)
# Out:
# 139746837760032

# %%
team_a.append("Axar")

# %%
team_a
# Out:
# ['Dhawan', 'Rahane', 'Ashwin', 'Axar']

# %%
team_b
# Out:
# ['Dhawan', 'Rahane', 'Ashwin', 'Axar']

# %%
team_b.append("Hardik")

# %%
team_b
# Out:
# ['Dhawan', 'Rahane', 'Ashwin', 'Axar', 'Hardik']

# %%
team_a
# Out:
# ['Dhawan', 'Rahane', 'Ashwin', 'Axar', 'Hardik']

# %% [markdown]
# ### Shallow Copy
# * list
# * [:]
# * copy

# %%
team_c = team_a[:]  ## Shallow Copy

# %%
team_a
# Out:
# ['Dhawan', 'Rahane', 'Ashwin', 'Axar', 'Hardik']

# %%
team_b
# Out:
# ['Dhawan', 'Rahane', 'Ashwin', 'Axar', 'Hardik']

# %%
team_c
# Out:
# ['Dhawan', 'Rahane', 'Ashwin', 'Axar', 'Hardik']

# %%
id(team_a)
# Out:
# 139746837760032

# %%
id(team_b)
# Out:
# 139746837760032

# %%
id(team_c)
# Out:
# 139746828634144

# %%
team_a.append("Pant")

# %%
team_a
# Out:
# ['Dhawan', 'Rahane', 'Ashwin', 'Axar', 'Hardik', 'Pant']

# %%
team_b
# Out:
# ['Dhawan', 'Rahane', 'Ashwin', 'Axar', 'Hardik', 'Pant']

# %%
team_c
# Out:
# ['Dhawan', 'Rahane', 'Ashwin', 'Axar', 'Hardik']

# %%
team_a
# Out:
# ['Dhawan', 'Rahane', 'Ashwin', 'Axar', 'Hardik', 'Pant']

# %%
id(team_a)
# Out:
# 139746837760032

# %%
id(team_b)
# Out:
# 139746837760032

# %%
id(team_c)
# Out:
# 139746828634144

# %%
team_a[0] = "Shikhar"

# %%
team_a
# Out:
# ['Shikhar', 'Rahane', 'Ashwin', 'Axar', 'Hardik', 'Pant']

# %%
team_b
# Out:
# ['Shikhar', 'Rahane', 'Ashwin', 'Axar', 'Hardik', 'Pant']

# %%
team_c
# Out:
# ['Dhawan', 'Rahane', 'Ashwin', 'Axar', 'Hardik']

# %%
team_d = list(team_a)  ## Shallow Copy

# %%
team_d
# Out:
# ['Shikhar', 'Rahane', 'Ashwin', 'Axar', 'Hardik', 'Pant']

# %%
id(team_a), id(team_b)
# Out:
# (139746837760032, 139746837760032)

# %%
id(team_c)
# Out:
# 139746828634144

# %%
id(team_d)
# Out:
# 139746828224544

# %%
team_a.append("Kuldeep")

# %%
team_a
# Out:
# ['Shikhar', 'Rahane', 'Ashwin', 'Axar', 'Hardik', 'Pant', 'Kuldeep']

# %%
team_b
# Out:
# ['Shikhar', 'Rahane', 'Ashwin', 'Axar', 'Hardik', 'Pant', 'Kuldeep']

# %%
team_d
# Out:
# ['Shikhar', 'Rahane', 'Ashwin', 'Axar', 'Hardik', 'Pant']

# %%
team_e = team_a.copy() # Shallow Copy

# %%
id(team_e)
# Out:
# 139746828325104

# %%
team_a
# Out:
# ['Shikhar', 'Rahane', 'Ashwin', 'Axar', 'Hardik', 'Pant', 'Kuldeep']

# %%
team_e
# Out:
# ['Shikhar', 'Rahane', 'Ashwin', 'Axar', 'Hardik', 'Pant', 'Kuldeep']

# %%
team_a.append("Jadeja")

# %%
team_a
# Out:
# ['Shikhar', 'Rahane', 'Ashwin', 'Axar', 'Hardik', 'Pant', 'Kuldeep', 'Jadeja']

# %%
team_b
# Out:
# ['Shikhar', 'Rahane', 'Ashwin', 'Axar', 'Hardik', 'Pant', 'Kuldeep', 'Jadeja']

# %%
team_e
# Out:
# ['Shikhar', 'Rahane', 'Ashwin', 'Axar', 'Hardik', 'Pant', 'Kuldeep']

# %%
list_1 = [100, [1, 2, 3], 200, 300]

# %%
list_2 = list_1.copy()

# %%
list_1
# Out:
# [100, [1, 2, 3], 200, 300]

# %%
list_2
# Out:
# [100, [1, 2, 3], 200, 300]

# %%
id(list_1)
# Out:
# 139746828715984

# %%
id(list_2)
# Out:
# 139746837355088

# %%
list_1.append(400)

# %%
list_1
# Out:
# [100, [1, 2, 3], 200, 300, 400]

# %%
list_2
# Out:
# [100, [1, 2, 3], 200, 300]

# %%
list_1[1]
# Out:
# [1, 2, 3]

# %%
list_1[1].append(4)

# %%
list_1
# Out:
# [100, [1, 2, 3, 4], 200, 300, 400]

# %%
list_2
# Out:
# [100, [1, 2, 3, 4], 200, 300]

# %%
list_1[1].append(5)

# %%
list_1
# Out:
# [100, [1, 2, 3, 4, 5], 200, 300, 400]

# %%
list_2
# Out:
# [100, [1, 2, 3, 4, 5], 200, 300]

# %%
list_1[1] = "18Mar2021"

# %%
list_1
# Out:
# [100, '18Mar2021', 200, 300, 400]

# %%
list_2
# Out:
# [100, [1, 2, 3, 4, 5], 200, 300]

# %% [markdown]
# ### Deep Copy

# %%
import copy

# %%
dc_1 = ['a', 'b', [100, 200, 300], 'c']

# %%
dc_2 = copy.deepcopy(dc_1)

# %%
dc_1
# Out:
# ['a', 'b', [100, 200, 300], 'c']

# %%
dc_2
# Out:
# ['a', 'b', [100, 200, 300], 'c']

# %%
dc_1.append('d')

# %%
dc_1
# Out:
# ['a', 'b', [100, 200, 300], 'c', 'd']

# %%
dc_2
# Out:
# ['a', 'b', [100, 200, 300], 'c']

# %%
dc_1[2].append(400)

# %%
dc_1
# Out:
# ['a', 'b', [100, 200, 300, 400], 'c', 'd']

# %%
dc_2
# Out:
# ['a', 'b', [100, 200, 300], 'c']

# %%
v = "Virat", 31, "RCB" # Packing

# %%
print(v)
# Out:
# ('Virat', 31, 'RCB')

# %%
type(v)
# Out:
# tuple

# %%
n, a, t = "Rohit", 33, "MI"

# %%
n
# Out:
# 'Rohit'

# %%
a
# Out:
# 33

# %%
t
# Out:
# 'MI'

# %%
type(n)
# Out:
# str

# %%
type(a)
# Out:
# int

# %%
type(t)
# Out:
# str

# %% [markdown]
# ### Practice Questions

# %%
a,b,c=1,2,3

# %%
a,b,c
# Out:
# (1, 2, 3)

# %%
print(a,b,c)
# Out:
# 1 2 3

# %%
c = ["India", "USA", "Srilanka"]

# %%
t_c = tuple(c)

# %%
t_c
# Out:
# ('India', 'USA', 'Srilanka')

# %%
lst_from_t = list(t_c)

# %%
lst_from_t
# Out:
# ['India', 'USA', 'Srilanka']

# %%
t = ()

# %%
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1 = ("18Mar2021")

# %%
t1
# Out:
# '18Mar2021'

# %%
type(t1)
# Out:
# str

# %%
t2 = ("18Mar",)

# %%
t2
# Out:
# ('18Mar',)

# %%
type(t2)
# Out:
# tuple

# %%
t2
# Out:
# ('18Mar',)

# %%
t2 * 5
# Out:
# ('18Mar', '18Mar', '18Mar', '18Mar', '18Mar')

# %%
t2[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-129-aade2f4ef3e1> in <module>()
# ----> 1 t2[1]
#
# IndexError: tuple index out of range

# %%
t2
# Out:
# ('18Mar',)

# %%
len(t2)
# Out:
# 1

# %%
t3 = "OneElement",

# %%
t3
# Out:
# ('OneElement',)

# %%
type(t3)
# Out:
# tuple
