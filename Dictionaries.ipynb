# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanvee0306/Python-For-Data-Scientist/blob/main/Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Dictionary
# Collection of key-value pairs
# Syntax: { }

# %%
# { K1: V1, K2: V2, K3: V3, K4: V4, ...}

# %%
fruits = {'a': 'apple', 'b': 'banana', 'c': 'cherry'}

# %%
print(fruits)
# Out:
# {'a': 'apple', 'b': 'banana', 'c': 'cherry'}

# %%
type(fruits)
# Out:
# dict

# %%
len(fruits)
# Out:
# 3

# %%
# In dict, the elements are accessed by key rather than index

# %%
fruits['a']
# Out:
# 'apple'

# %%
fruits['b']
# Out:
# 'banana'

# %%
# Add elements to the dictionary
fruits['w'] = 'watermelon'

# %%
fruits
# Out:
# {'a': 'apple', 'b': 'banana', 'c': 'cherry', 'w': 'watermelon'}

# %%
fruits['p'] = 'papaya'

# %%
fruits
# Out:
# {'a': 'apple', 'b': 'banana', 'c': 'cherry', 'p': 'papaya', 'w': 'watermelon'}

# %%
fruits['a'] = 'apricot'

# %%
fruits
# Out:
# {'a': 'apricot',
#  'b': 'banana',
#  'c': 'cherry',
#  'p': 'papaya',
#  'w': 'watermelon'}

# %%
fruits['d'] = 'apricot'

# %%
fruits
# Out:
# {'a': 'apricot',
#  'b': 'banana',
#  'c': 'cherry',
#  'd': 'apricot',
#  'p': 'papaya',
#  'w': 'watermelon'}

# %%
ipl = {}

# %%
len(ipl)
# Out:
# 0

# %%
ipl['MI'] = ["Rohit", "Surya"]

# %%
ipl
# Out:
# {'MI': ['Rohit', 'Surya']}

# %%
ipl["RCB"] = ("Virat", "ABD")

# %%
ipl
# Out:
# {'MI': ['Rohit', 'Surya'], 'RCB': ('Virat', 'ABD')}

# %%
ipl["RCB"] = ["Virat", "ABD"]

# %%
ipl
# Out:
# {'MI': ['Rohit', 'Surya'], 'RCB': ['Virat', 'ABD']}

# %%
ipl['MI']
# Out:
# ['Rohit', 'Surya']

# %%
ipl['MI'].append("Bumrah")

# %%
ipl
# Out:
# {'MI': ['Rohit', 'Surya', 'Bumrah'], 'RCB': ['Virat', 'ABD']}

# %%
ipl["Mumbai"] = ipl["MI"]

# %%
ipl
# Out:
# {'MI': ['Rohit', 'Surya', 'Bumrah'],
#  'Mumbai': ['Rohit', 'Surya', 'Bumrah'],
#  'RCB': ['Virat', 'ABD']}

# %%
ipl['MI'].append("Hardik")

# %%
ipl
# Out:
# {'MI': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'Mumbai': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'RCB': ['Virat', 'ABD']}

# %%
ipl["Bangalore"] = ['Virat', "ABD"]

# %%
ipl
# Out:
# {'Bangalore': ['Virat', 'ABD'],
#  'MI': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'Mumbai': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'RCB': ['Virat', 'ABD']}

# %%
ipl['RCB'].append("Yuzi")

# %%
ipl
# Out:
# {'Bangalore': ['Virat', 'ABD'],
#  'MI': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'Mumbai': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'RCB': ['Virat', 'ABD', 'Yuzi']}

# %%
# in operator
'MI' in ipl
# Out:
# True

# %%
"mi" in ipl
# Out:
# False

# %%
ipl['mi'] = 'lower case of MI'

# %%
ipl
# Out:
# {'Bangalore': ['Virat', 'ABD'],
#  'MI': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'Mumbai': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'RCB': ['Virat', 'ABD', 'Yuzi'],
#  'mi': 'lower case of MI'}

# %%
ipl.get('MI')
# Out:
# ['Rohit', 'Surya', 'Bumrah', 'Hardik']

# %%
result = ipl.get("CSK")

# %%
print(result)
# Out:
# None

# %%
ipl['CSK']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-2769b5392d40> in <module>()
# ----> 1 ipl['CSK']
#
# KeyError: 'CSK'

# %%
result = ipl.get("CSK", -1)

# %%
result
# Out:
# -1

# %%
result = ipl.get("MI", -1)

# %%
result
# Out:
# ['Rohit', 'Surya', 'Bumrah', 'Hardik']

# %%
ipl.get("CSK", -1)
# Out:
# -1

# %%
ipl.items()
# Out:
# dict_items([('MI', ['Rohit', 'Surya', 'Bumrah', 'Hardik']), ('RCB', ['Virat', 'ABD', 'Yuzi']), ('Mumbai', ['Rohit', 'Surya', 'Bumrah', 'Hardik']), ('Bangalore', ['Virat', 'ABD']), ('mi', 'lower case of MI')])

# %%
# [('MI', ['Rohit', 'Surya', 'Bumrah', 'Hardik']), ('RCB', ['Virat', 'ABD', 'Yuzi']), ...]

# %%
ipl.keys()
# Out:
# dict_keys(['MI', 'RCB', 'Mumbai', 'Bangalore', 'mi'])

# %%
ipl.values()
# Out:
# dict_values([['Rohit', 'Surya', 'Bumrah', 'Hardik'], ['Virat', 'ABD', 'Yuzi'], ['Rohit', 'Surya', 'Bumrah', 'Hardik'], ['Virat', 'ABD'], 'lower case of MI'])

# %%
fruits
# Out:
# {'a': 'apricot',
#  'b': 'banana',
#  'c': 'cherry',
#  'd': 'apricot',
#  'p': 'papaya',
#  'w': 'watermelon'}

# %%
fruits.items()
# Out:
# dict_items([('a', 'apricot'), ('b', 'banana'), ('c', 'cherry'), ('w', 'watermelon'), ('p', 'papaya'), ('d', 'apricot')])

# %%
fruits.items()[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-e0b1f60cdeff> in <module>()
# ----> 1 fruits.items()[0]
#
# TypeError: 'dict_items' object is not subscriptable

# %%
list(fruits.items())[0]
# Out:
# ('a', 'apricot')

# %%
list(fruits.items())[0][1]
# Out:
# 'apricot'

# %%
fruits
# Out:
# {'a': 'apricot',
#  'b': 'banana',
#  'c': 'cherry',
#  'd': 'apricot',
#  'p': 'papaya',
#  'w': 'watermelon'}

# %%
ipl
# Out:
# {'Bangalore': ['Virat', 'ABD'],
#  'MI': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'Mumbai': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'RCB': ['Virat', 'ABD', 'Yuzi'],
#  'mi': 'lower case of MI'}

# %%
# pop
fruits.pop("csk")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-001e2ca8d0ac> in <module>()
#       1 # pop
# ----> 2 fruits.pop("csk")
#
# KeyError: 'csk'

# %%
fruits.pop('d')
# Out:
# 'apricot'

# %%
fruits
# Out:
# {'a': 'apricot',
#  'b': 'banana',
#  'c': 'cherry',
#  'p': 'papaya',
#  'w': 'watermelon'}

# %%
fruits.pop('o')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-867d3c65e34a> in <module>()
# ----> 1 fruits.pop('o')
#
# KeyError: 'o'

# %%
fruits.pop('o', -1)
# Out:
# -1

# %%
# popitem
fruits.popitem()
# Out:
# ('p', 'papaya')

# %%
fruits
# Out:
# {'a': 'apricot', 'b': 'banana', 'c': 'cherry', 'w': 'watermelon'}

# %%
ipl
# Out:
# {'Bangalore': ['Virat', 'ABD'],
#  'MI': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'Mumbai': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'RCB': ['Virat', 'ABD', 'Yuzi'],
#  'mi': 'lower case of MI'}

# %%
ipl['RCB'].remove('Yuzi')

# %%
ipl
# Out:
# {'Bangalore': ['Virat', 'ABD'],
#  'MI': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'Mumbai': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'RCB': ['Virat', 'ABD'],
#  'mi': 'lower case of MI'}

# %%
del ipl['mi']

# %%
ipl
# Out:
# {'Bangalore': ['Virat', 'ABD'],
#  'MI': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'Mumbai': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'RCB': ['Virat', 'ABD']}

# %%
lst = [100, 200, 300]

# %%
lst.pop(-1)
# Out:
# 300

# %%
lst
# Out:
# [100, 200]

# %%
ipl['RCB'].pop(-1)
# Out:
# 'ABD'

# %%
ipl
# Out:
# {'Bangalore': ['Virat', 'ABD'],
#  'MI': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'Mumbai': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'RCB': ['Virat']}

# %%
fruits
# Out:
# {'a': 'apricot', 'b': 'banana', 'c': 'cherry', 'w': 'watermelon'}

# %%
alphabets = {'a': 100, 'b': 200}

# %%
alphabets
# Out:
# {'a': 100, 'b': 200}

# %%
fruits.update(alphabets)

# %%
fruits
# Out:
# {'a': 100, 'b': 200, 'c': 'cherry', 'w': 'watermelon'}

# %%
ipl
# Out:
# {'Bangalore': ['Virat', 'ABD'],
#  'MI': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'Mumbai': ['Rohit', 'Surya', 'Bumrah', 'Hardik'],
#  'RCB': ['Virat']}

# %%
del ipl["MI"][0]

# %%
ipl
# Out:
# {'Bangalore': ['Virat', 'ABD'],
#  'MI': ['Surya', 'Bumrah', 'Hardik'],
#  'Mumbai': ['Surya', 'Bumrah', 'Hardik'],
#  'RCB': ['Virat']}

# %%
fruits
# Out:
# {'a': 100, 'b': 200, 'c': 'cherry', 'w': 'watermelon'}

# %%
alphabets
# Out:
# {'a': 100, 'b': 200}

# %%
new_d = {'u': 'update', 'c': 'chikku', 'p': 'papaya'}

# %%
new_d
# Out:
# {'c': 'chikku', 'p': 'papaya', 'u': 'update'}

# %%
fruits
# Out:
# {'a': 100, 'b': 200, 'c': 'cherry', 'w': 'watermelon'}

# %%
fruits.update(new_d)

# %%
fruits
# Out:
# {'a': 100,
#  'b': 200,
#  'c': 'chikku',
#  'p': 'papaya',
#  'u': 'update',
#  'w': 'watermelon'}

# %%
fruits[1] = "integer key"

# %%
fruits
# Out:
# {1: 'integer key',
#  'a': 100,
#  'b': 200,
#  'c': 'chikku',
#  'p': 'papaya',
#  'u': 'update',
#  'w': 'watermelon'}

# %%
fruits[(1, 2,3)] = "tuple as key"

# %%
fruits
# Out:
# {(1, 2, 3): 'tuple as key',
#  1: 'integer key',
#  'a': 100,
#  'b': 200,
#  'c': 'chikku',
#  'p': 'papaya',
#  'u': 'update',
#  'w': 'watermelon'}

# %%
fruits['N'] = None

# %%
fruits
# Out:
# {(1, 2, 3): 'tuple as key',
#  1: 'integer key',
#  'N': None,
#  'a': 100,
#  'b': 200,
#  'c': 'chikku',
#  'p': 'papaya',
#  'u': 'update',
#  'w': 'watermelon'}

# %%
fruits.clear()

# %%
fruits
# Out:
# {}

# %%
ipl
# Out:
# {'Bangalore': ['Virat', 'ABD'],
#  'MI': ['Surya', 'Bumrah', 'Hardik'],
#  'Mumbai': ['Surya', 'Bumrah', 'Hardik'],
#  'RCB': ['Virat']}

# %%
ipl.clear()

# %%
ipl
# Out:
# {}
